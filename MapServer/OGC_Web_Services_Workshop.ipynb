# %% [markdown]
# # MapServer OGC Web Services Workshop
#
# ## Content
#
# **[1. Introduction](#Introduction)**
#
# **[2. WMS](#WMS)**
#
#   * [DescribeLayer](#DescribeLayer)
#   * [GetMap](#GetMap)
#
# **[3. WFS](#WFS)**
#
#   * [DescribeFeatureType](#DescribeFeatureType)
#   * [GetFeature](#GetFeature)
#
# **[4. WCS](#WCS)**
#
#   * [DescribeCoverage](#DescribeCoverage)
#   * [GetCoverage](#GetCoverage)
#
# ----
#
# ## Introduction
#
# First of all, you will start by running the following command to ensure that your mapfiles can be used with the latest MapServer version.
#
# Make sure to run this command only once after starting the tale!

# %%
# !echo ${REPO_DIR}; rm -rf ms-ogc-workshop; git clone https://github.com/MapServer/ms-ogc-workshop.git ; \
    sed "s:/opt/mapserver:${REPO_DIR}/MapServer/ms-ogc-workshop/service:g" -i ~/.local/etc/mapserver-sample.conf ;\
    for i in ms-ogc-workshop/service/*.map; do echo $i;  sed "s:CONFIG:#CONFIG:g;s:DUMP:#DUMP:g;s:COLOR 0 0 255:STYLE COLOR 0 0 255 END:g" -i $i ; done
# Out:
# /WholeTale/workspace
# Cloning into 'ms-ogc-workshop'...
# remote: Enumerating objects: 1001, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1001 (delta 11), reused 13 (delta 1), pack-reused 976
# Receiving objects: 100% (1001/1001), 4.40 MiB | 18.11 MiB/s, done.
# Resolving deltas: 100% (611/611), done.
# ms-ogc-workshop/service/config.map
# ms-ogc-workshop/service/exercise_answer.map
# ms-ogc-workshop/service/exercise.map

# %%
# !pip3 install display_xml opencv-python matplotlib geopandas geojson earthpy
# Out:
# Requirement already satisfied: display_xml in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.1.0)
# Requirement already satisfied: opencv-python in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.5.5.64)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.5.2)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.10.2)
# Requirement already satisfied: geojson in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.5.0)
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 10.4 MB/s eta 0:00:01
# Requirement already satisfied: lxml>=4.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from display_xml) (4.9.0)
# Requirement already satisfied: pygments>=2.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from display_xml) (2.6.1)
# Requirement already satisfied: ipython>=6.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from display_xml) (7.16.1)
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (20.4)
# Requirement already satisfied: pyproj>=2.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: pandas>=0.25.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: shapely>=1.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopandas) (1.8.2)
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 42.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from earthpy) (2.24.0)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.7/site-packages (from earthpy) (1.2.10)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (3.0.5)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (0.17.2)
# Requirement already satisfied: traitlets>=4.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (4.3.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (4.8.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=6.2.1->display_xml) (49.2.0.post20200712)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.2.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyproj>=2.2.0->geopandas) (2020.6.20)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (2022.1)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (19.3.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 51.8 MB/s eta 0:00:01
# Collecting imageio>=2.4.1
#   Downloading imageio-2.19.3-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 36.1 MB/s eta 0:00:01
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 46.1 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 65.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-image->earthpy) (1.7.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->earthpy) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->earthpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->earthpy) (2.10)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.7/site-packages (from rasterio->earthpy) (2.3.1)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.2.1->display_xml) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jedi>=0.10->ipython>=6.2.1->display_xml) (0.7.1)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets>=4.2->ipython>=6.2.1->display_xml) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=6.2.1->display_xml) (0.6.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from click>=4.0->fiona>=1.8->geopandas) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click>=4.0->fiona>=1.8->geopandas) (3.1.0)
# Installing collected packages: PyWavelets, imageio, networkx, tifffile, scikit-image, earthpy
# Successfully installed PyWavelets-1.3.0 earthpy-0.9.4 imageio-2.19.3 networkx-2.6.3 scikit-image-0.19.3 tifffile-2021.11.2

# %% [markdown]
# ## WMS
#
# ### Overview
#
# HTTP based (GET or POST)
#
# Operations:
#
#   * GetCapabilities
#   * DescribeLayer
#   * GetMap
#   * GetFeatureInfo
#
#  * Operation keywords are CaSe-InSeNsItIvE
#  * Operation values are case-sensitive
#
#
# ### GetCapabilities
#  * Provides XML of service functionality metadata, and layer metadata
#  * Parameters:
#    * **Version** (version of specification)‏
#    * **Service** (multiple services may exist from this service, e.g. WMS, WFS, WCS)‏
#    * **Request** (GetCapabilities)‏
#
# #### Example

# %%
import requests, os
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.1.1&service=WMS&request=GetCapabilities&'

XML(requests.get(url).content, style='perldoc')
# Out:
#     <div class=abb0c462a-9c37-4e98-b8a0-9e7462d65c69>
#         <style>
#             div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .hll { background-color: #ffffcc }
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .c { color: #228B22 } /* Comment */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .ch { color: #228B22 } /* Comment.Hashbang */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .cm { color: #228B22 } /* Comment.Multiline */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .cp { color: #1e889b } /* Comment.Preproc */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .c1 { color: #228B22 } /* Comment.Single */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gd { color: #aa0000 } /* Generic.Deleted */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .ge { font-style: italic } /* Generic.Emph */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gr { color: #aa0000 } /* Generic.Error */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gi { color: #00aa00 } /* Generic.Inserted */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .go { color: #888888 } /* Generic.Output */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gp { color: #555555 } /* Generic.Prompt */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gs { font-weight: bold } /* Generic.Strong */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .gt { color: #aa0000 } /* Generic.Traceback */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .m { color: #B452CD } /* Literal.Number */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .s { color: #CD5555 } /* Literal.String */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .na { color: #658b00 } /* Name.Attribute */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nb { color: #658b00 } /* Name.Builtin */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .no { color: #00688B } /* Name.Constant */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nd { color: #707a7c } /* Name.Decorator */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nf { color: #008b45 } /* Name.Function */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .nv { color: #00688B } /* Name.Variable */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .ow { color: #8B008B } /* Operator.Word */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .w { color: #bbbbbb } /* Text.Whitespace */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .mb { color: #B452CD } /* Literal.Number.Bin */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .mf { color: #B452CD } /* Literal.Number.Float */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .mh { color: #B452CD } /* Literal.Number.Hex */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .mi { color: #B452CD } /* Literal.Number.Integer */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .mo { color: #B452CD } /* Literal.Number.Oct */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sa { color: #CD5555 } /* Literal.String.Affix */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sc { color: #CD5555 } /* Literal.String.Char */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sd { color: #CD5555 } /* Literal.String.Doc */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .s2 { color: #CD5555 } /* Literal.String.Double */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .se { color: #CD5555 } /* Literal.String.Escape */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .si { color: #CD5555 } /* Literal.String.Interpol */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sx { color: #cb6c20 } /* Literal.String.Other */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .s1 { color: #CD5555 } /* Literal.String.Single */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .fm { color: #008b45 } /* Name.Function.Magic */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .vc { color: #00688B } /* Name.Variable.Class */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .vg { color: #00688B } /* Name.Variable.Global */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .vi { color: #00688B } /* Name.Variable.Instance */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .vm { color: #00688B } /* Name.Variable.Magic */
# div.abb0c462a-9c37-4e98-b8a0-9e7462d65c69 .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;WMT_MS_Capabilities</span> <span class="na">version=</span><span class="s">&quot;1.1.1&quot;</span><span class="nt">&gt;</span>
#   <span class="c">&lt;!-- MapServer version 7.7-dev OUTPUT=PNG OUTPUT=JPEG OUTPUT=KML SUPPORTS=PROJ SUPPORTS=AGG SUPPORTS=FREETYPE SUPPORTS=CAIRO SUPPORTS=ICONV SUPPORTS=FRIBIDI SUPPORTS=WMS_SERVER SUPPORTS=WMS_CLIENT SUPPORTS=WFS_SERVER SUPPORTS=WFS_CLIENT SUPPORTS=WCS_SERVER SUPPORTS=OGCAPI_SERVER SUPPORTS=FASTCGI SUPPORTS=GEOS SUPPORTS=PBF INPUT=JPEG INPUT=POSTGIS INPUT=OGR INPUT=GDAL INPUT=SHAPEFILE --&gt;</span>
#   <span class="nt">&lt;Service&gt;</span>
#     <span class="nt">&lt;Name&gt;</span>OGC:WMS<span class="nt">&lt;/Name&gt;</span>
#     <span class="nt">&lt;Title&gt;</span>Sample OWS for MapServer OGC Web Services Workshop<span class="nt">&lt;/Title&gt;</span>
#     <span class="nt">&lt;Abstract&gt;</span>Sample OWS for MapServer OGC Web Services Workshop.  Enjoy!<span class="nt">&lt;/Abstract&gt;</span>
#     <span class="nt">&lt;KeywordList&gt;</span>
#       <span class="nt">&lt;Keyword&gt;</span>mapserver<span class="nt">&lt;/Keyword&gt;</span>
#       <span class="nt">&lt;Keyword&gt;</span>ogc<span class="nt">&lt;/Keyword&gt;</span>
#       <span class="nt">&lt;Keyword&gt;</span>workshop<span class="nt">&lt;/Keyword&gt;</span>
#     <span class="nt">&lt;/KeywordList&gt;</span>
#     <span class="nt">&lt;OnlineResource</span> <span class="na">xmlns:xlink=</span><span class="s">&quot;http://www.w3.org/1999/xlink&quot;</span> <span class="na">xlink:href=</span><span class="s">&quot;http://localhost/ms-ogc-workshop/index.html&quot;</span><span class="nt">/&gt;</span>
#     <span class="nt">&lt;ContactInformation&gt;</span>
#       <span class="nt">&lt;ContactPersonPrimary&gt;</span>
#         <span class="nt">&lt;Contact

# %% [markdown]
# ### DescribeLayer
#
# OPTIONAL operation to provide more information about a WMS layer (WFS, etc.)
#
# Parameters:
#   * **VERSION**
#   * **SERVICE**
#   * **REQUEST**
#   * **LAYERS**
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.1.1&service=WMS&request=DescribeLayer&layers=rivers'

XML(requests.get(url).content, style='perldoc')
# Out:
#     <div class=a76373223-4cd8-44d7-9d39-2604c7c3051b>
#         <style>
#             div.a76373223-4cd8-44d7-9d39-2604c7c3051b .hll { background-color: #ffffcc }
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .c { color: #228B22 } /* Comment */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .ch { color: #228B22 } /* Comment.Hashbang */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .cm { color: #228B22 } /* Comment.Multiline */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .cp { color: #1e889b } /* Comment.Preproc */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .c1 { color: #228B22 } /* Comment.Single */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gd { color: #aa0000 } /* Generic.Deleted */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .ge { font-style: italic } /* Generic.Emph */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gr { color: #aa0000 } /* Generic.Error */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gi { color: #00aa00 } /* Generic.Inserted */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .go { color: #888888 } /* Generic.Output */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gp { color: #555555 } /* Generic.Prompt */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gs { font-weight: bold } /* Generic.Strong */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .gt { color: #aa0000 } /* Generic.Traceback */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .m { color: #B452CD } /* Literal.Number */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .s { color: #CD5555 } /* Literal.String */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .na { color: #658b00 } /* Name.Attribute */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nb { color: #658b00 } /* Name.Builtin */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .no { color: #00688B } /* Name.Constant */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nd { color: #707a7c } /* Name.Decorator */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nf { color: #008b45 } /* Name.Function */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .nv { color: #00688B } /* Name.Variable */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .ow { color: #8B008B } /* Operator.Word */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .w { color: #bbbbbb } /* Text.Whitespace */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .mb { color: #B452CD } /* Literal.Number.Bin */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .mf { color: #B452CD } /* Literal.Number.Float */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .mh { color: #B452CD } /* Literal.Number.Hex */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .mi { color: #B452CD } /* Literal.Number.Integer */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .mo { color: #B452CD } /* Literal.Number.Oct */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sa { color: #CD5555 } /* Literal.String.Affix */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sc { color: #CD5555 } /* Literal.String.Char */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sd { color: #CD5555 } /* Literal.String.Doc */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .s2 { color: #CD5555 } /* Literal.String.Double */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .se { color: #CD5555 } /* Literal.String.Escape */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .si { color: #CD5555 } /* Literal.String.Interpol */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sx { color: #cb6c20 } /* Literal.String.Other */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .s1 { color: #CD5555 } /* Literal.String.Single */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .fm { color: #008b45 } /* Name.Function.Magic */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .vc { color: #00688B } /* Name.Variable.Class */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .vg { color: #00688B } /* Name.Variable.Global */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .vi { color: #00688B } /* Name.Variable.Instance */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .vm { color: #00688B } /* Name.Variable.Magic */
# div.a76373223-4cd8-44d7-9d39-2604c7c3051b .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;WMS_DescribeLayerResponse</span> <span class="na">version=</span><span class="s">&quot;1.1.1&quot;</span><span class="nt">&gt;</span>
#   <span class="nt">&lt;LayerDescription</span> <span class="na">name=</span><span class="s">&quot;rivers&quot;</span> <span class="na">wfs=</span><span class="s">&quot;http://localhost/cgi-bin/mapserv.exe?map=@osgeo4w@/apps/ms-ogc-workshop/service/config.map&quot;</span> <span class="na">owsType=</span><span class="s">&quot;WFS&quot;</span> <span class="na">owsURL=</span><span class="s">&quot;http://localhost/cgi-bin/mapserv.exe?map=@osgeo4w@/apps/ms-ogc-workshop/service/config.map&quot;</span><span class="nt">&gt;</span>
#     <span class="nt">&lt;Query</span> <span class="na">typeName=</span><span class="s">&quot;rivers&quot;</span><span class="nt">/&gt;</span>
#   <span class="nt">&lt;/LayerDescription&gt;</span>
# <span class="nt">&lt;/WMS_DescribeLayerResponse&gt;</span>
# </pre></div>
#
#     </div>

# %% [markdown]
# ### GetMap
#
# * Returns graphic image of data based on area of interest, data, etc.
# * Image, not features, not attributes
# * Parameters
#  * version (version of specification)‏
#  * service (multiple services may exists from this service, e.g. WMS, WFS, WCS)‏
#  * request (GetMap)‏
#  * format (image format to be returned)‏
#    * Get this from GetCapabilities info
#  * bbox (spatial area of interest, i.e. minx,miny,maxx,maxy)‏
#  * srs (reference system / projection of bounding box coordinates
#    * EPSG (http://www.epsg.org/)‏
#    * Get supported SRSs from GetCapabilities
#  * Most widely used SRS is EPSG:4326
#    * Lat/long geographic (WGS84)‏
#  * width (output image width)‏
#  * height (output image height)‏
#  * layers  (data desired to be visualized)‏
#    * Get this from GetCapabilities info
#    * Comma-separated list
#      * Eg. Layers=elevation,roads,railways,…
#      * First list item is bottom most output layer
#  * TIME (Not all WMS implementations support TIME)
#    * ISO 8601 formatted timestring
#    * Single point
#    * Frequency
#    * Range
#    * Current
#  * Styles (desired portrayal of data)‏
#    * Get this from GetCapabilities info per layer
#    * Comma-separated list
#      * e.g.. layers=elevation,roads,railways&styles=default,red,blue
#      * Style list MUST align with layer list
#      * Empty list value for non styled layers
#      * e.g. to style ONLY railways layer: layers=elevation,roads,railways&styles=,,blue
#  * Styles and SLD
#    * SLD enables remote classification and symbolization of data
#    * Overrides server-based styles if request from user
#    * To use in GetMap, SLD document must exist over HTTP, and cited in GetMap request
#      * &sld=http://localhost/ms_ogc_workshop/sld/rivers.sld
#      * OR &sld_body=<entire_sld_document>
#      * (consider HTTP POST for SLD_BODY)‏
#      * More info on SLD later
#  * transparent (whether to make non-opaque data pixels transparent
#    * Either TRUE or FALSE
#    * Useful for layering data from multiple remote WMS services atop eachother for map composition
#    * Depends on image format (JPEG is not transparent)‏
#    * Depends on web browser support
#    * GIF transparency is supported in all browsers
#    * PNG transparency support in newer browsers
#  * bgcolor (optional background color of image)
#  * Exceptions (how to handle errors)‏
#    * Can be caused by:
#    * Server malfunction
#    * Invalid client syntax (missing required values, etc.)‏
#      * application/vnd.ogc.se_xml
#      * application/vnd.ogc.se_inimage
#      * application/vnd.ogc.se_blank
#  * Exceptions
#    * Which one should I use?
#    * application/vnd.ogc.se_inimage
#      * Useful for easily visualizing errors in your app
#      * Can also be ugly to the end-user / audience
#    * application/vnd.ogc.se_blank
#      * Returns a blank image
#      * Difficult to recognize what type or error has occurred
#    * application/vnd.ogc.se_xml
#      * Returns an XML exception document
#      * Difficult to decode if your app is requesting an image type
#      * Choose accordingly
#
#
#
# #### Example

# %%
from IPython.display import Image
import requests

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.1.1&service=WMS&request=GetMap&srs=EPSG:4326&bbox=-180,-90,180,90&format=image/png&layers=land_shallow_topo_2048,rivers&transparent=true&width=1000&height=600&styles='

Image(requests.get(url).content)

# %% [markdown]
# ## WFS
#
# * Feature level access to spatial data (vectors)‏
# * Rich query interface
# * Returns GML
# * Transactional capability
#  * Security considerations for OGC:WFS-T
#    * MapServer supports basic WFS
#    * No transactions (except using TinyOWS)
# * Operations
#  * GetCapabilities
#  * DescribeFeatureType
#  * GetFeature
#
# ### GetCapabilities
#
# * Same idea as OGC:WMS GetCapabilities
# * Parameters
#  * VERSION
#  * SERVICE
#  * REQUEST
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WFS&request=GetCapabilities'

XML(requests.get(url).content, style='perldoc')
# Out:
#     <div class=ad16932b8-3d60-46e2-94b3-c16112535ec4>
#         <style>
#             div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .hll { background-color: #ffffcc }
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .c { color: #228B22 } /* Comment */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .ch { color: #228B22 } /* Comment.Hashbang */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .cm { color: #228B22 } /* Comment.Multiline */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .cp { color: #1e889b } /* Comment.Preproc */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .c1 { color: #228B22 } /* Comment.Single */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gd { color: #aa0000 } /* Generic.Deleted */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .ge { font-style: italic } /* Generic.Emph */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gr { color: #aa0000 } /* Generic.Error */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gi { color: #00aa00 } /* Generic.Inserted */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .go { color: #888888 } /* Generic.Output */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gp { color: #555555 } /* Generic.Prompt */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gs { font-weight: bold } /* Generic.Strong */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .gt { color: #aa0000 } /* Generic.Traceback */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .m { color: #B452CD } /* Literal.Number */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .s { color: #CD5555 } /* Literal.String */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .na { color: #658b00 } /* Name.Attribute */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nb { color: #658b00 } /* Name.Builtin */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .no { color: #00688B } /* Name.Constant */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nd { color: #707a7c } /* Name.Decorator */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nf { color: #008b45 } /* Name.Function */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .nv { color: #00688B } /* Name.Variable */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .ow { color: #8B008B } /* Operator.Word */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .w { color: #bbbbbb } /* Text.Whitespace */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .mb { color: #B452CD } /* Literal.Number.Bin */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .mf { color: #B452CD } /* Literal.Number.Float */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .mh { color: #B452CD } /* Literal.Number.Hex */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .mi { color: #B452CD } /* Literal.Number.Integer */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .mo { color: #B452CD } /* Literal.Number.Oct */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sa { color: #CD5555 } /* Literal.String.Affix */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sc { color: #CD5555 } /* Literal.String.Char */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sd { color: #CD5555 } /* Literal.String.Doc */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .s2 { color: #CD5555 } /* Literal.String.Double */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .se { color: #CD5555 } /* Literal.String.Escape */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .si { color: #CD5555 } /* Literal.String.Interpol */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sx { color: #cb6c20 } /* Literal.String.Other */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .s1 { color: #CD5555 } /* Literal.String.Single */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .fm { color: #008b45 } /* Name.Function.Magic */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .vc { color: #00688B } /* Name.Variable.Class */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .vg { color: #00688B } /* Name.Variable.Global */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .vi { color: #00688B } /* Name.Variable.Instance */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .vm { color: #00688B } /* Name.Variable.Magic */
# div.ad16932b8-3d60-46e2-94b3-c16112535ec4 .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;WFS_Capabilities</span> <span class="na">xmlns=</span><span class="s">&quot;http://www.opengis.net/wfs&quot;</span> <span class="na">xmlns:ogc=</span><span class="s">&quot;http://www.opengis.net/ogc&quot;</span> <span class="na">xmlns:xsi=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema-instance&quot;</span> <span class="na">version=</span><span class="s">&quot;1.0.0&quot;</span> <span class="na">updateSequence=</span><span class="s">&quot;0&quot;</span> <span class="na">xsi:schemaLocation=</span><span class="s">&quot;http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.0.0/WFS-capabilities.xsd&quot;</span><span class="nt">&gt;</span>
#   <span class="c">&lt;!-- MapServer version 7.7-dev OUTPUT=PNG OUTPUT=JPEG OUTPUT=KML SUPPORTS=PROJ SUPPORTS=AGG SUPPORTS=FREETYPE SUPPORTS=CAIRO SUPPORTS=ICONV SUPPORTS=FRIBIDI SUPPORTS=WMS_SERVER SUPPORTS=WMS_CLIENT SUPPORTS=WFS_SERVER SUPPORTS=WFS_CLIENT SUPPORTS=WCS_SERVER SUPPORTS=OGCAPI_SERVER SUPPORTS=FASTCGI SUPPORTS=GEOS SUPPORTS=PBF INPUT=JPEG INPUT=POSTGIS INPUT=OGR INPUT=GDAL INPUT=SHAPEFILE --&gt;</span>
#   <span class="nt">&lt;Service&gt;</span>
#     <span class="nt">&lt;Name&gt;</span>MapServer WFS<span class="nt">&lt;/Name&gt;</span>
#     <span class="nt">&lt;Title&gt;</span>Sample OWS for MapServer OGC Web Services Workshop<span class="nt">&lt;/Title&gt;</span>
#     <span class="nt">&lt;Abstract&gt;</span>Sample OWS for MapServer OGC Web Services Workshop.  Enjoy!<span class="nt">&lt;/Abstract&gt;</span>
#     <span class="nt">&lt;Keywords&gt;</span>
#     mapserver
#     ogc
#     workshop
#   <span class="nt">&lt;/Keywords&gt;</span>
#     <span class="nt">&lt;OnlineResource&gt;</span>http://localhost/ms-ogc-workshop/index.html<span class="nt">&lt;/OnlineResource&gt;</span>
#     <span

# %% [markdown]
# ### DescribeFeatureType
#
# * Provides an outline of the structure of a feature type (fields, etc.)‏
# * Analogous to SQL describe <table> command
# * Parameters
#  * VERSION
#  * SERVICE
#  * REQUEST
#  * TYPENAME
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WFS&request=DescribeFeatureType&typename=rivers'

XML(requests.get(url).content, style='perldoc')
# Out:
#     <div class=a7bb4ea5f-5801-4349-baba-664664fea0c4>
#         <style>
#             div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .hll { background-color: #ffffcc }
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .c { color: #228B22 } /* Comment */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .ch { color: #228B22 } /* Comment.Hashbang */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .cm { color: #228B22 } /* Comment.Multiline */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .cp { color: #1e889b } /* Comment.Preproc */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .c1 { color: #228B22 } /* Comment.Single */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gd { color: #aa0000 } /* Generic.Deleted */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .ge { font-style: italic } /* Generic.Emph */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gr { color: #aa0000 } /* Generic.Error */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gi { color: #00aa00 } /* Generic.Inserted */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .go { color: #888888 } /* Generic.Output */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gp { color: #555555 } /* Generic.Prompt */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gs { font-weight: bold } /* Generic.Strong */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .gt { color: #aa0000 } /* Generic.Traceback */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .m { color: #B452CD } /* Literal.Number */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .s { color: #CD5555 } /* Literal.String */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .na { color: #658b00 } /* Name.Attribute */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nb { color: #658b00 } /* Name.Builtin */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .no { color: #00688B } /* Name.Constant */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nd { color: #707a7c } /* Name.Decorator */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nf { color: #008b45 } /* Name.Function */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .nv { color: #00688B } /* Name.Variable */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .ow { color: #8B008B } /* Operator.Word */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .w { color: #bbbbbb } /* Text.Whitespace */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .mb { color: #B452CD } /* Literal.Number.Bin */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .mf { color: #B452CD } /* Literal.Number.Float */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .mh { color: #B452CD } /* Literal.Number.Hex */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .mi { color: #B452CD } /* Literal.Number.Integer */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .mo { color: #B452CD } /* Literal.Number.Oct */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sa { color: #CD5555 } /* Literal.String.Affix */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sc { color: #CD5555 } /* Literal.String.Char */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sd { color: #CD5555 } /* Literal.String.Doc */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .s2 { color: #CD5555 } /* Literal.String.Double */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .se { color: #CD5555 } /* Literal.String.Escape */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .si { color: #CD5555 } /* Literal.String.Interpol */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sx { color: #cb6c20 } /* Literal.String.Other */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .s1 { color: #CD5555 } /* Literal.String.Single */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .fm { color: #008b45 } /* Name.Function.Magic */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .vc { color: #00688B } /* Name.Variable.Class */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .vg { color: #00688B } /* Name.Variable.Global */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .vi { color: #00688B } /* Name.Variable.Instance */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .vm { color: #00688B } /* Name.Variable.Magic */
# div.a7bb4ea5f-5801-4349-baba-664664fea0c4 .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;schema</span> <span class="na">xmlns:ms-ogc-workshop=</span><span class="s">&quot;http://localhost/ms-ogc-workshop&quot;</span> <span class="na">xmlns:ogc=</span><span class="s">&quot;http://www.opengis.net/ogc&quot;</span> <span class="na">xmlns:xsd=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema&quot;</span> <span class="na">xmlns=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema&quot;</span> <span class="na">xmlns:gml=</span><span class="s">&quot;http://www.opengis.net/gml&quot;</span> <span class="na">targetNamespace=</span><span class="s">&quot;http://localhost/ms-ogc-workshop&quot;</span> <span class="na">elementFormDefault=</span><span class="s">&quot;qualified&quot;</span> <span class="na">version=</span><span class="s">&quot;0.1&quot;</span><span class="nt">&gt;</span>
#   <span class="nt">&lt;import</span> <span class="na">namespace=</span><span class="s">&quot;http://www.opengis.net/gml&quot;</span> <span class="na">schemaLocation=</span><span class="s">&quot;http://schemas.opengis.net/gml/2.1.2/feature.xsd&quot;</span><span class="nt">/&gt;</span>
#   <span class="nt">&lt;element</span> <span class="na">name=</span><span class="s">&quot;rivers&quot;</span> <span class="na">type=</span><span class="s">&quot;ms-ogc-workshop:riversType&quot;</span> <span class="na">substitutionGroup=</span><span class="s">&quot;gml:_Feature&quot;</span><span class="nt">/&gt;</span>
#   <span class="nt">&lt;complexType</span> <span class="na">name=</span><span class="s">&quot;riversType&quot;</span><span class="nt">&gt;</span>
#     <span class="nt">&lt;complexContent&gt;</span>
#       <span class="nt">&lt;extension</span> <span class="na">base=</span><span class="s">&quot;gml:AbstractFeatureType&quot;</span><span class="nt">&gt

# %% [markdown]
# ### GetFeature
#
# * Provides an outline of the structure of a feature type (fields, etc.)‏
# * Analogous to SQL describe <table> command
# * Parameters
#  * VERSION
#  * SERVICE
#  * REQUEST
#  * TYPENAME
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WFS&request=GetFeature&typename=rivers&maxfeatures=1'

XML(requests.get(url).content, style='perldoc')
# Out:
#     <div class=ac774b4a9-84e4-4dea-8c18-089d830bccc4>
#         <style>
#             div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .hll { background-color: #ffffcc }
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .c { color: #228B22 } /* Comment */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .ch { color: #228B22 } /* Comment.Hashbang */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .cm { color: #228B22 } /* Comment.Multiline */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .cp { color: #1e889b } /* Comment.Preproc */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .c1 { color: #228B22 } /* Comment.Single */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gd { color: #aa0000 } /* Generic.Deleted */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .ge { font-style: italic } /* Generic.Emph */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gr { color: #aa0000 } /* Generic.Error */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gi { color: #00aa00 } /* Generic.Inserted */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .go { color: #888888 } /* Generic.Output */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gp { color: #555555 } /* Generic.Prompt */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gs { font-weight: bold } /* Generic.Strong */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .gt { color: #aa0000 } /* Generic.Traceback */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .m { color: #B452CD } /* Literal.Number */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .s { color: #CD5555 } /* Literal.String */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .na { color: #658b00 } /* Name.Attribute */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nb { color: #658b00 } /* Name.Builtin */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .no { color: #00688B } /* Name.Constant */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nd { color: #707a7c } /* Name.Decorator */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nf { color: #008b45 } /* Name.Function */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .nv { color: #00688B } /* Name.Variable */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .ow { color: #8B008B } /* Operator.Word */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .w { color: #bbbbbb } /* Text.Whitespace */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .mb { color: #B452CD } /* Literal.Number.Bin */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .mf { color: #B452CD } /* Literal.Number.Float */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .mh { color: #B452CD } /* Literal.Number.Hex */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .mi { color: #B452CD } /* Literal.Number.Integer */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .mo { color: #B452CD } /* Literal.Number.Oct */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sa { color: #CD5555 } /* Literal.String.Affix */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sc { color: #CD5555 } /* Literal.String.Char */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sd { color: #CD5555 } /* Literal.String.Doc */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .s2 { color: #CD5555 } /* Literal.String.Double */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .se { color: #CD5555 } /* Literal.String.Escape */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .si { color: #CD5555 } /* Literal.String.Interpol */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sx { color: #cb6c20 } /* Literal.String.Other */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .s1 { color: #CD5555 } /* Literal.String.Single */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .fm { color: #008b45 } /* Name.Function.Magic */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .vc { color: #00688B } /* Name.Variable.Class */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .vg { color: #00688B } /* Name.Variable.Global */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .vi { color: #00688B } /* Name.Variable.Instance */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .vm { color: #00688B } /* Name.Variable.Magic */
# div.ac774b4a9-84e4-4dea-8c18-089d830bccc4 .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;wfs:FeatureCollection</span> <span class="na">xmlns:ms-ogc-workshop=</span><span class="s">&quot;http://localhost/ms-ogc-workshop&quot;</span> <span class="na">xmlns:wfs=</span><span class="s">&quot;http://www.opengis.net/wfs&quot;</span> <span class="na">xmlns:gml=</span><span class="s">&quot;http://www.opengis.net/gml&quot;</span> <span class="na">xmlns:ogc=</span><span class="s">&quot;http://www.opengis.net/ogc&quot;</span> <span class="na">xmlns:xsi=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema-instance&quot;</span> <span class="na">xsi:schemaLocation=</span><span class="s">&quot;http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.0.0/WFS-basic.xsd                         http://localhost/ms-ogc-workshop http://localhost/cgi-bin/mapserv.exe?map=@osgeo4w@/apps/ms-ogc-workshop/service/config.map&amp;amp;SERVICE=WFS&amp;amp;VERSION=1.0.0&amp;amp;REQUEST=DescribeFeatureType&amp;amp;TYPENAME=rivers&amp;amp;OUTPUTFORMAT=XMLSCHEMA&quot;</span><span class="nt">&gt;</span>
#   <span class="nt">&lt;gml:boundedBy&gt;</span>
#     <span class="nt">&lt;gml:Box</span> <span class="na">srsName=</span><span class="s">&quot;EPSG:4326&quot;</span><span class="nt">&gt;</span>
#       <span class="nt">&lt;gml:coordinates&gt;</span>123.259560,56.472576 136.084991,63.546486<span class="nt">&lt;/gml:coordinates&gt;</span>
#     <span class="nt">&lt;/gml:Box&gt;</span>
#   <span class="nt">&lt;/gml:boundedBy&gt;</span>
#   <span class="nt">&lt;gml:featureMember&gt;</span>
#     <span class="nt">&lt;ms-ogc-workshop:rivers&gt;</span>
#       <span class="nt">&lt;gml:boundedBy&gt;</span>
#         <span class="nt">&lt;gml:Box</span> <span class="na">srsName=</span><span class="s">&quot;EPSG:4326&quot;</span><span class="nt">&gt;</span>
#           <span c

# %%
import geopandas as gpd
from pyproj import CRS
import requests
import geojson

# Specify the url for web feature service

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map'

# Specify parameters (read data in json format).
# Available feature types in this particular data source: http://geo.stat.fi/geoserver/vaestoruutu/wfs?service=wfs&version=2.0.0&request=describeFeatureType
params = dict(service='WFS',
              version='2.0.0',
              request='GetFeature',
              typeName='rivers',
              outputformat='geojson'
             )

# Fetch data from WFS using requests
r = requests.get(url, params=params)

#print(r.content)

# Create GeoDataFrame from geojson
data = gpd.GeoDataFrame.from_features(geojson.loads(r.content))
# Clean overall cell
# Check the data
data.head()
# Out:
#                                             geometry       NAME  SYSTEM
# 0  LINESTRING (124.00678 56.47258, 123.25956 56.6...      Aldan    Lena
# 1  MULTILINESTRING ((-61.27730 -3.60706, -60.6846...     Amazon  Amazon
# 2  LINESTRING (73.98818 37.49952, 73.52595 37.528...  Amu Darya
# 3  LINESTRING (122.63956 49.99730, 120.47874 49.2...       Amur
# 4  LINESTRING (105.07841 51.93053, 103.92959 51.7...     Angara

# %%
import folium

import panel as pn

pn.extension(sizing_mode="stretch_width")


m = folium.Map(location=[40, 10], zoom_start=4, control_scale=True, prefer_canvas=True)

folium_pane = pn.pane.plot.Folium(m, height=400)


style = {'fillColor': '#f5f5f5', 'lineColor': '#000000', 'weight': 10.2}    
#polygon = folium.GeoJson(geojson.loads(r.content), style_function = lambda x: style).add_to(m)

style_function = lambda x: {'fillColor': '#ffffff',
                            'color':'#6666ff', 
                            'fillOpacity': 0.1, 
                            'weight': 6.2}
highlight_function = lambda x: {'fillColor': '#000000',
                                'color':'#0000ff', 
                                'fillOpacity': 0.50, 
                                'weight': 6.2}
polygon = folium.features.GeoJson(
    data = geojson.loads(r.content),
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function, 
    tooltip=folium.features.GeoJsonTooltip(
        fields=['NAME'],
        aliases=['NAME'],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;") 
    )
).add_to(m)


folium.LayerControl().add_to(m)

folium_pane.object = m

folium_pane
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Folium(Map, height=400)

# %% [markdown]
# ## WCS
#
# * The raster equivalent to OGC:WFS
# * Provides “real” raster data
#   * DEM
#   * GeoTIFF
#
#
# * Operations
#  * GetCapabilities
#  * DescribeCoverage
#  * GetCoverage
#
# ### GetCapabilities
#
#  * Same idea as OGC:WMS GetCapabilities
#  * Parameters
#   * VERSION
#   * SERVICE
#   * REQUEST
#
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WCS&request=GetCapabilities'

print(url)
XML(requests.get(url).content, style='perldoc')
# Out:
# http://localhost:8000/cgi-bin/mapserv?map=/WholeTale/workspace/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WCS&request=GetCapabilities
#     <div class=a8b7d02ef-c58b-4ae7-a500-d019ccac07f2>
#         <style>
#             div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .hll { background-color: #ffffcc }
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .c { color: #228B22 } /* Comment */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .ch { color: #228B22 } /* Comment.Hashbang */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .cm { color: #228B22 } /* Comment.Multiline */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .cp { color: #1e889b } /* Comment.Preproc */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .c1 { color: #228B22 } /* Comment.Single */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gd { color: #aa0000 } /* Generic.Deleted */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .ge { font-style: italic } /* Generic.Emph */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gr { color: #aa0000 } /* Generic.Error */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gi { color: #00aa00 } /* Generic.Inserted */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .go { color: #888888 } /* Generic.Output */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gp { color: #555555 } /* Generic.Prompt */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gs { font-weight: bold } /* Generic.Strong */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .gt { color: #aa0000 } /* Generic.Traceback */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .m { color: #B452CD } /* Literal.Number */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .s { color: #CD5555 } /* Literal.String */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .na { color: #658b00 } /* Name.Attribute */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nb { color: #658b00 } /* Name.Builtin */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .no { color: #00688B } /* Name.Constant */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nd { color: #707a7c } /* Name.Decorator */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nf { color: #008b45 } /* Name.Function */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .nv { color: #00688B } /* Name.Variable */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .ow { color: #8B008B } /* Operator.Word */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .w { color: #bbbbbb } /* Text.Whitespace */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .mb { color: #B452CD } /* Literal.Number.Bin */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .mf { color: #B452CD } /* Literal.Number.Float */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .mh { color: #B452CD } /* Literal.Number.Hex */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .mi { color: #B452CD } /* Literal.Number.Integer */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .mo { color: #B452CD } /* Literal.Number.Oct */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sa { color: #CD5555 } /* Literal.String.Affix */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sc { color: #CD5555 } /* Literal.String.Char */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sd { color: #CD5555 } /* Literal.String.Doc */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .s2 { color: #CD5555 } /* Literal.String.Double */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .se { color: #CD5555 } /* Literal.String.Escape */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .si { color: #CD5555 } /* Literal.String.Interpol */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sx { color: #cb6c20 } /* Literal.String.Other */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .s1 { color: #CD5555 } /* Literal.String.Single */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .fm { color: #008b45 } /* Name.Function.Magic */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .vc { color: #00688B } /* Name.Variable.Class */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .vg { color: #00688B } /* Name.Variable.Global */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .vi { color: #00688B } /* Name.Variable.Instance */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .vm { color: #00688B } /* Name.Variable.Magic */
# div.a8b7d02ef-c58b-4ae7-a500-d019ccac07f2 .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;WCS_Capabilities</span> <span class="na">xmlns=</span><span class="s">&quot;http://www.opengis.net/wcs&quot;</span> <span class="na">xmlns:xlink=</span><span class="s">&quot;http://www.w3.org/1999/xlink&quot;</span> <span class="na">xmlns:gml=</span><span class="s">&quot;http://www.opengis.net/gml&quot;</span> <span class="na">xmlns:xsi=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema-instance&quot;</span> <span class="na">version=</span><span class="s">&quot;1.0.0&quot;</span> <span class="na">updateSequence=</span><span class="s">&quot;0&quot;</span> <span class="na">xsi:schemaLocation=</span><span class="s">&quot;http://www.opengis.net/wcs http://schemas.opengis.net/wcs/1.0.0/wcsCapabilities.xsd&quot;</span><span class="nt">&gt;</span>
#   <span class="nt">&lt;Service&gt;</span>
#     <span class="nt">&lt;metadataLink</span> <span class="na">metadataType=</span><span class="s">&quot;other&quot;</span> <span class="na">xlink:type=</span><span class="s">&quot;simple&quot;</span> <span class="na">xlink:href=</span><span class="s">&quot;http://localhost/ms-ogc-workshop/index.html&quot;</span><span class="nt">/&gt;</span>
#     <span class="nt">&lt;description&gt;</span>Sample OWS for MapServer OGC Web Services Workshop.  Enjoy!<span class="nt">&lt;/description&gt;</span>
#     <span class="nt">&lt;name&gt;</span>MapServer WCS<span class="nt">&lt;/name&gt;</span>
#     <span class="nt">&lt;label&gt;</span>Sample OWS for MapServer OGC Web Services Workshop<span class="nt">&lt;/label&gt;</span>
#     <span class="nt">&lt;keywords&gt;</span>
#       <span class="nt">&lt;keyword&gt;</span>mapserver<span class="nt">&lt;/keyword&gt;</span>
#       <span class="nt">&lt;keyword&gt;</span>ogc<span class="nt">&lt;/keyword&gt;</span>
#       <span class=

# %% [markdown]
# ### DescribeCoverage
#
# * Provides an outline of the structure of a coverage
#  * bands
#  * resolution
# * Parameters
#   * VERSION
#   * SERVICE
#   * REQUEST
#   * COVERAGE
#
# #### Example

# %%
import requests
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WCS&request=DescribeCoverage&coverage=toronto'

print(url)
XML(requests.get(url).content, style='perldoc')
# Out:
# http://localhost:8000/cgi-bin/mapserv?map=/WholeTale/workspace/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WCS&request=DescribeCoverage&coverage=toronto
#     <div class=a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d>
#         <style>
#             div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .hll { background-color: #ffffcc }
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .c { color: #228B22 } /* Comment */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .ch { color: #228B22 } /* Comment.Hashbang */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .cm { color: #228B22 } /* Comment.Multiline */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .cp { color: #1e889b } /* Comment.Preproc */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .c1 { color: #228B22 } /* Comment.Single */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .cs { color: #8B008B; font-weight: bold } /* Comment.Special */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gd { color: #aa0000 } /* Generic.Deleted */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .ge { font-style: italic } /* Generic.Emph */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gr { color: #aa0000 } /* Generic.Error */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gi { color: #00aa00 } /* Generic.Inserted */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .go { color: #888888 } /* Generic.Output */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gp { color: #555555 } /* Generic.Prompt */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gs { font-weight: bold } /* Generic.Strong */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .gt { color: #aa0000 } /* Generic.Traceback */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kc { color: #8B008B; font-weight: bold } /* Keyword.Constant */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kd { color: #8B008B; font-weight: bold } /* Keyword.Declaration */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kn { color: #8B008B; font-weight: bold } /* Keyword.Namespace */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kp { color: #8B008B; font-weight: bold } /* Keyword.Pseudo */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kr { color: #8B008B; font-weight: bold } /* Keyword.Reserved */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .kt { color: #00688B; font-weight: bold } /* Keyword.Type */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .m { color: #B452CD } /* Literal.Number */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .s { color: #CD5555 } /* Literal.String */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .na { color: #658b00 } /* Name.Attribute */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nb { color: #658b00 } /* Name.Builtin */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nc { color: #008b45; font-weight: bold } /* Name.Class */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .no { color: #00688B } /* Name.Constant */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nd { color: #707a7c } /* Name.Decorator */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .ne { color: #008b45; font-weight: bold } /* Name.Exception */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nf { color: #008b45 } /* Name.Function */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nn { color: #008b45; text-decoration: underline } /* Name.Namespace */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nt { color: #8B008B; font-weight: bold } /* Name.Tag */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .nv { color: #00688B } /* Name.Variable */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .ow { color: #8B008B } /* Operator.Word */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .w { color: #bbbbbb } /* Text.Whitespace */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .mb { color: #B452CD } /* Literal.Number.Bin */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .mf { color: #B452CD } /* Literal.Number.Float */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .mh { color: #B452CD } /* Literal.Number.Hex */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .mi { color: #B452CD } /* Literal.Number.Integer */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .mo { color: #B452CD } /* Literal.Number.Oct */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sa { color: #CD5555 } /* Literal.String.Affix */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sb { color: #CD5555 } /* Literal.String.Backtick */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sc { color: #CD5555 } /* Literal.String.Char */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .dl { color: #CD5555 } /* Literal.String.Delimiter */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sd { color: #CD5555 } /* Literal.String.Doc */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .s2 { color: #CD5555 } /* Literal.String.Double */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .se { color: #CD5555 } /* Literal.String.Escape */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sh { color: #1c7e71; font-style: italic } /* Literal.String.Heredoc */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .si { color: #CD5555 } /* Literal.String.Interpol */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sx { color: #cb6c20 } /* Literal.String.Other */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .sr { color: #1c7e71 } /* Literal.String.Regex */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .s1 { color: #CD5555 } /* Literal.String.Single */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .ss { color: #CD5555 } /* Literal.String.Symbol */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .bp { color: #658b00 } /* Name.Builtin.Pseudo */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .fm { color: #008b45 } /* Name.Function.Magic */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .vc { color: #00688B } /* Name.Variable.Class */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .vg { color: #00688B } /* Name.Variable.Global */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .vi { color: #00688B } /* Name.Variable.Instance */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .vm { color: #00688B } /* Name.Variable.Magic */
# div.a2f3e8f00-e125-4496-bff2-ffe5b0c7ac6d .il { color: #B452CD } /* Literal.Number.Integer.Long */
#         </style>
#         <div class="highlight"><pre><span></span><span class="nt">&lt;CoverageDescription</span> <span class="na">xmlns=</span><span class="s">&quot;http://www.opengis.net/wcs&quot;</span> <span class="na">xmlns:xlink=</span><span class="s">&quot;http://www.w3.org/1999/xlink&quot;</span> <span class="na">xmlns:gml=</span><span class="s">&quot;http://www.opengis.net/gml&quot;</span> <span class="na">xmlns:xsi=</span><span class="s">&quot;http://www.w3.org/2001/XMLSchema-instance&quot;</span> <span class="na">version=</span><span class="s">&quot;1.0.0&quot;</span> <span class="na">updateSequence=</span><span class="s">&quot;0&quot;</span> <span class="na">xsi:schemaLocation=</span><span class="s">&quot;http://www.opengis.net/wcs http://schemas.opengis.net/wcs/1.0.0/describeCoverage.xsd&quot;</span><span class="nt">&gt;</span>
#   <span class="nt">&lt;CoverageOffering&gt;</span>
#     <span class="nt">&lt;metadataLink</span> <span class="na">metadataType=</span><span class="s">&quot;other&quot;</span> <span class="na">xlink:type=</span><span class="s">&quot;simple&quot;</span> <span class="na">xlink:href=</span><span class="s">&quot;http://geogratis.cgdi.gc.ca/clf/en?action=fullMetadata&amp;amp;entryId=4373&quot;</span><span class="nt">/&gt;</span>
#     <span class="nt">&lt;description&gt;</span>Toronto Landsat 5 TM<span class="nt">&lt;/description&gt;</span>
#     <span class="nt">&lt;name&gt;</span>toronto<span class="nt">&lt;/name&gt;</span>
#     <span class="nt">&lt;label&gt;</span>Landsat 5 TM - Toronto<span class="nt">&lt;/label&gt;</span>
#     <span class="nt">&lt;lonLatEnvelope</span> <span class="na">srsName=</span><span class="s">&quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;</span><span class="nt">&gt;</span>
#       <span class="nt">&lt;gml:pos&gt;</span>-81.5452675343946 42.7135512181332<span class="nt">&lt;/gm

# %% [markdown]
# ### GetCoverage
#
# * Gimme data!
# * Parameters:
#  * VERSION
#  * SERVICE
#  * REQUEST
#  * COVERAGE
#  * CRS
#  * BBOX
#
# #### Example
#
# We first store the response provided by the WCS server on the `GetCoverage` request, then we display it using [OpenCV](https://opencv.org/).

# %%
import requests
import os
import cv2
#import matplotlib.pyplot as plt
from display_xml import XML

url='http://localhost:8000/cgi-bin/mapserv?map='+os.environ['REPO_DIR']+'/MapServer/ms-ogc-workshop/service/config.map&version=1.0.0&service=WCS&request=GetCoverage&coverage=toronto&crs=EPSG:26917&resx=500&resy=500&format=GEOTIFF_RGB&BBOX=456850,4732100,706850,4957100'

file=open("./toto.tiff","wb")
file.write(requests.get(url).content)

train_tiffs = os.listdir("./")

for tiff in train_tiffs:
    if tiff.count('tif'):
        print(tiff)
        im = cv2.imread("./" + tiff)
        plt.imshow(im)
        plt.show()
# Out:
# toto.tiff
